# %%
import pandas as pd
dataset = pd.read_csv("rawpvr_2018-02-01_28d_1083 TueFri.csv", index_col = False)
dataset.head()
# Out:
#                          Date  Lane Lane Name  Direction Direction Name  \
# 0  2018-02-02 00:00:03.050000     6     SB_NS          2          South
# 1  2018-02-02 00:00:22.010000     5    SB_MID          2          South
# 2  2018-02-02 00:00:22.020000     4     SB_OS          2          South
# 3  2018-02-02 00:00:36.040000     6     SB_NS          2          South
# 4  2018-02-02 00:00:49.070000     6     SB_NS          2          South
#
#    Speed (mph)  Headway (s)  Gap (s)  Flags  Flag Text
# 0       38.525          NaN      NaN      0        NaN
# 1       32.310          NaN      NaN      0        NaN
# 2       44.739          NaN      NaN      0        NaN
# 3       33.554          NaN      NaN      0        NaN
# 4       39.768         12.3   11.847      0        NaN

# %%
dataset.info()
type(dataset.Date[0]) # 确认数据类型
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503768 entries, 0 to 503767
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Date            503768 non-null  object
#  1   Lane            503768 non-null  int64
#  2   Lane Name       503768 non-null  object
#  3   Direction       503768 non-null  int64
#  4   Direction Name  503768 non-null  object
#  5   Speed (mph)     503749 non-null  float64
#  6   Headway (s)     493776 non-null  float64
#  7   Gap (s)         489693 non-null  float64
#  8   Flags           503768 non-null  int64
#  9   Flag Text       0 non-null       float64
# dtypes: float64(4), int64(3), object(3)
# memory usage: 38.4+ MB
# str

# %%
dataset['Date'].value_counts()
# Out:
# 2018-02-13 17:21:23.010000    4
# 2018-02-06 18:04:51.050000    4
# 2018-02-23 08:34:04.070000    4
# 2018-02-16 17:22:24.050000    4
# 2018-02-20 13:32:46.080000    4
#                              ..
# 2018-02-23 13:12:06.020000    1
# 2018-02-13 18:05:47.040000    1
# 2018-02-02 19:33:36.080000    1
# 2018-02-20 06:00:05.010000    1
# 2018-02-23 16:32:57.060000    1
# Name: Date, Length: 484874, dtype: int64

# %%
from datetime import datetime
# print(str(dataset.Date.apply(lambda s: s[:19])))
# print(dataset.Date)
dataset['Flags'] = dataset['Date'].apply(lambda s : datetime.strptime(s[:19], "%Y-%m-%d %H:%M:%S").weekday()+1)

# %%
dataset.head()
# Out:
#                          Date  Lane Lane Name  Direction Direction Name  \
# 0  2018-02-02 00:00:03.050000     6     SB_NS          2          South
# 1  2018-02-02 00:00:22.010000     5    SB_MID          2          South
# 2  2018-02-02 00:00:22.020000     4     SB_OS          2          South
# 3  2018-02-02 00:00:36.040000     6     SB_NS          2          South
# 4  2018-02-02 00:00:49.070000     6     SB_NS          2          South
#
#    Speed (mph)  Headway (s)  Gap (s)  Flags  Flag Text
# 0       38.525          NaN      NaN      5        NaN
# 1       32.310          NaN      NaN      5        NaN
# 2       44.739          NaN      NaN      5        NaN
# 3       33.554          NaN      NaN      5        NaN
# 4       39.768         12.3   11.847      5        NaN

# %%
week_day_dict = {
        1: 'Monday', 
        2: 'Tuesday',
        3: 'Wednesday',
        4: 'Thursday',
        5: 'Friday',
        6: 'Saturday',
        7: 'Sunday',
}

dataset['Flag Text'] = dataset['Flags'].apply(lambda s : week_day_dict[s])

# %%
dataset.head()
# Out:
#                          Date  Lane Lane Name  Direction Direction Name  \
# 0  2018-02-02 00:00:03.050000     6     SB_NS          2          South
# 1  2018-02-02 00:00:22.010000     5    SB_MID          2          South
# 2  2018-02-02 00:00:22.020000     4     SB_OS          2          South
# 3  2018-02-02 00:00:36.040000     6     SB_NS          2          South
# 4  2018-02-02 00:00:49.070000     6     SB_NS          2          South
#
#    Speed (mph)  Headway (s)  Gap (s)  Flags Flag Text
# 0       38.525          NaN      NaN      5    Friday
# 1       32.310          NaN      NaN      5    Friday
# 2       44.739          NaN      NaN      5    Friday
# 3       33.554          NaN      NaN      5    Friday
# 4       39.768         12.3   11.847      5    Friday

# %%
traffic_volume = {}
dataset['Flags'].value_counts()
# Out:
# 5    255751
# 2    248017
# Name: Flags, dtype: int64

# %%
traffic_volume['Tue'] = dataset['Flags'].value_counts()[2]
traffic_volume['Fri'] = dataset['Flags'].value_counts()[5]

# %%
traffic_volume
# Out:
# {'Tue': 248017, 'Fri': 255751}

# %%
# create a column to describe time（hour）
dataset['Hours'] = dataset['Date'].apply(lambda s : datetime.strptime(s[:19], "%Y-%m-%d %H:%M:%S").hour)
dataset.describe()
# Out:
#                 Lane      Direction    Speed (mph)    Headway (s)  \
# count  503768.000000  503768.000000  503749.000000  493776.000000
# mean        3.577770       1.499293      31.708125       6.828993
# std         1.787199       0.500000       7.847538      11.965522
# min         1.000000       1.000000       1.244000       0.053000
# 25%         2.000000       1.000000      27.962000       1.916000
# 50%         3.000000       1.000000      32.310000       3.012000
# 75%         5.000000       2.000000      36.039000       6.300000
# max         6.000000       2.000000     121.168000     292.300000
#
#              Gap (s)          Flags          Hours
# count  489693.000000  503768.000000  503768.000000
# mean        6.404432       3.523028      13.198242
# std        12.038498       1.499825       4.750324
# min         0.001000       2.000000       0.000000
# 25%         1.340000       2.000000       9.000000
# 50%         2.475000       5.000000      14.000000
# 75%         6.013000       5.000000      17.000000
# max       291.855000       5.000000      23.000000

# %%
dataset.head()
# Out:
#                          Date  Lane Lane Name  Direction Direction Name  \
# 0  2018-02-02 00:00:03.050000     6     SB_NS          2          South
# 1  2018-02-02 00:00:22.010000     5    SB_MID          2          South
# 2  2018-02-02 00:00:22.020000     4     SB_OS          2          South
# 3  2018-02-02 00:00:36.040000     6     SB_NS          2          South
# 4  2018-02-02 00:00:49.070000     6     SB_NS          2          South
#
#    Speed (mph)  Headway (s)  Gap (s)  Flags Flag Text  Hours
# 0       38.525          NaN      NaN      5    Friday      0
# 1       32.310          NaN      NaN      5    Friday      0
# 2       44.739          NaN      NaN      5    Friday      0
# 3       33.554          NaN      NaN      5    Friday      0
# 4       39.768         12.3   11.847      5    Friday      0

# %%
# create a label for day(date without time)
dataset['Day_of_the_month'] = dataset['Date'].apply(lambda s : datetime.strptime(s[:19], "%Y-%m-%d %H:%M:%S").day)

# %%
dataset.head()
# Out:
#                          Date  Lane Lane Name  Direction Direction Name  \
# 0  2018-02-02 00:00:03.050000     6     SB_NS          2          South
# 1  2018-02-02 00:00:22.010000     5    SB_MID          2          South
# 2  2018-02-02 00:00:22.020000     4     SB_OS          2          South
# 3  2018-02-02 00:00:36.040000     6     SB_NS          2          South
# 4  2018-02-02 00:00:49.070000     6     SB_NS          2          South
#
#    Speed (mph)  Headway (s)  Gap (s)  Flags Flag Text  Hours  Day_of_the_month
# 0       38.525          NaN      NaN      5    Friday      0                 2
# 1       32.310          NaN      NaN      5    Friday      0                 2
# 2       44.739          NaN      NaN      5    Friday      0                 2
# 3       33.554          NaN      NaN      5    Friday      0                 2
# 4       39.768         12.3   11.847      5    Friday      0                 2

# %%
tmp = dataset.loc[dataset["Flags"] == 2]
tmp = tmp.loc[dataset['Hours'] == 9]
tmp = tmp.loc[dataset['Direction'] == 1]
traffic_volume_for_Tue = tmp.groupby(['Day_of_the_month']).size()

# %%
traffic_volume_for_Tue
# Out:
# Day_of_the_month
# 6     2537
# 13    2447
# 20    2311
# 27    2426
# dtype: int64

# %%
traffic_volume_for_Tue.rename('volume', inplace=True)
# Out:
# Day_of_the_month
# 6     2537
# 13    2447
# 20    2311
# 27    2426
# Name: volume, dtype: int64

# %%
traffic_volume_for_Tue.describe()
# Out:
# count       4.000000
# mean     2430.250000
# std        92.942186
# min      2311.000000
# 25%      2397.250000
# 50%      2436.500000
# 75%      2469.500000
# max      2537.000000
# Name: volume, dtype: float64

# %%
volume_range = max(traffic_volume_for_Tue) - min(traffic_volume_for_Tue)

# %%
volume_range
# Out:
# 226

# %%
interquartile_range = traffic_volume_for_Tue.quantile(0.75) - traffic_volume_for_Tue.quantile(0.25)

# %%
interquartile_range
# Out:
# 72.25

# %%
# 每个小时的平均车流量 按照小时算，然后/4
north_volume_per_hour = dataset.loc[dataset['Flags'] == 2].loc[dataset['Direction'] == 1].groupby(['Hours']).size()

# %%
north_volume_per_hour /= 4

# %%
south_volume_per_hour = dataset.loc[dataset['Flags'] == 2].loc[dataset['Direction'] == 2].groupby(['Hours']).size()

# %%
south_volume_per_hour /= 4

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
north_volume_per_hour.plot.bar(x="Hours", title="volume for north")
for i, v in enumerate(north_volume_per_hour):
    plt.text(i-0.5, v + 1, str(v), fontsize=7)
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
south_volume_per_hour.plot.bar(x="Hours", title="volume for south")
for i, v in enumerate(south_volume_per_hour):
    plt.text(i-0.5, v + 1, str(v), fontsize=7)
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# use a dictionary to store the Column Completeness.
Column_Completeness = {}

# get all Tuesday
condition = dataset.loc[dataset['Flags'] == 2]

# get the time between 7:00 - 19:00. 'Flags' refers to the day of the week, which has been gotten in task 1.
condition = tmp.loc[(dataset['Hours'] >= 7) & (dataset['Hours'] < 19)]

# get the quality assessment of the level of completeness of the 'Gaps(s)'. 
Column_Completeness['Gap (s)'] = condition['Gap (s)'].isnull().sum() * 100 / condition['Gap (s)'].count()

# get the quality assessment of the level of completeness of the ''Headways(s)'.  'Hours' refers to the hours of a day, which I defined in task 2.
Column_Completeness['Headway (s)'] = condition['Headway (s)'].isnull().sum() * 100 / condition['Headway (s)'].count()

Column_Completeness
# Out:
# {'Gap (s)': 1.8012357314902083, 'Headway (s)': 0.7148777455449647}
